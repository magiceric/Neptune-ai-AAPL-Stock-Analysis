# %%
import time
from StockAnalysisTool import StockAnalysisTool

# Define a global variable for the current timestamp
global_timestamp = time.strftime("%Y-%m-%d_%H-%M-%S")

# Loop through the next 10 stock codes (assuming sequential numerical increment)
for i in range(10):
    stock_code = f"{int('000001') + i:06d}.SZ"  # Format to keep leading zeros and append .SZ
    tool = StockAnalysisTool(stock_code, global_timestamp)
    basic_info = tool.get_basic_info()
    print(basic_info)

# %%
from TushareCaller import TushareCaller

# Create an instance of TushareCaller
tushare_caller = TushareCaller()

# Define the stock code
stock_code = "000001.SZ"

# Call the Tushare API 200 times as per the instructions
for _ in range(10):
    stock_info = tushare_caller.call_api('stock_basic', exchange='', list_status='L', fields='ts_code,symbol,name,area,industry,list_date', ts_code=stock_code)
    print(stock_info)

del tushare_caller

# %%
import logging
import time
import sys
from tqdm import tqdm
from utils.StockHistoryFetcher import StockHistoryFetcher

# Setup logging
log_filename = f"logs/history_fetcher_{time.strftime('%Y%m%d')}.log"
logging.basicConfig(filename=log_filename, level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', encoding='utf-8')

# Redirect stderr to log file
original_stderr = sys.stderr  # Save the original stderr
log_file = open(log_filename, 'a', encoding='utf-8')

# Create an instance of StockHistoryFetcher
fetcher = StockHistoryFetcher(None)

try:
    
    # Get all stock codes
    # Redirect stdout to log file for fetcher outputs
    original_stdout = sys.stdout  # Save the original stdout
    sys.stdout = log_file
    all_stock_codes_df = fetcher.fetch_all_stock_codes()
    # Loop through all stock codes and fetch historical data for each with a progress bar
    # sys.stdout = original_stdout  # Restore stdout to console after fetching

    for index, row in tqdm(all_stock_codes_df.iterrows(), total=all_stock_codes_df.shape[0], desc="Fetching History", file=sys.stdout):
        stock_code = row['code']
        fetcher.stock_code = stock_code  # Update the stock code in fetcher
        logging.info(f"Fetching history for stock code: {stock_code}")
        
        # sys.stdout = log_file  # Redirect stdout to log file
        fetcher.fetch_history()
        sys.stdout = original_stdout  # Restore stdout to console after fetching
finally:
    # Ensure resources are released after fetching is done
    logging.info("Completed fetching all stock histories.")
    del fetcher

# Restore stderr
log_file.close()

logging.shutdown()
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]
# 最新日期 :  2024-05-20
# 成功获取000002的历史数据
# 成功将000002的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000004的历史数据
# 成功将000004的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000006的历史数据
# 成功将000006的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000007的历史数据
# 成功将000007的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000008的历史数据
# 成功将000008的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000009的历史数据
# 成功将000009的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000010的历史数据
# 成功将000010的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000011的历史数据
# 成功将000011的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000012的历史数据
# 成功将000012的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000014的历史数据
# 成功将000014的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000016的历史数据
# 成功将000016的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000017的历史数据
# 成功将000017的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000019的历史数据
# 成功将000019的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000020的历史数据
# 成功将000020的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000021的历史数据
# 成功将000021的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000023的历史数据
# 成功将000023的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000025的历史数据
# 成功将000025的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000026的历史数据
# 成功将000026的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000027的历史数据
# 成功将000027的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000028的历史数据
# 成功将000028的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000029的历史数据
# 成功将000029的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000030的历史数据
# 成功将000030的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000031的历史数据
# 成功将000031的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000032的历史数据
# 成功将000032的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000034的历史数据
# 成功将000034的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000035的历史数据
# 成功将000035的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000036的历史数据
# 成功将000036的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000037的历史数据
# 成功将000037的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000039的历史数据
# 成功将000039的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-04-30
# 成功获取000040的历史数据
# 成功将000040的历史数据逐条更新或插入到数据库，处理数据条数：1
# 最新日期 :  2024-05-20
# 成功获取000042的历史数据
# 成功将000042的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000045的历史数据
# 成功将000045的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000048的历史数据
# 成功将000048的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000049的历史数据
# 成功将000049的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000050的历史数据
# 成功将000050的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000055的历史数据
# 成功将000055的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000056的历史数据
# 成功将000056的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000058的历史数据
# 成功将000058的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000059的历史数据
# 成功将000059的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000060的历史数据
# 成功将000060的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000061的历史数据
# 成功将000061的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000062的历史数据
# 成功将000062的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000063的历史数据
# 成功将000063的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000065的历史数据
# 成功将000065的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000066的历史数据
# 成功将000066的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000068的历史数据
# 成功将000068的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000069的历史数据
# 成功将000069的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000070的历史数据
# 成功将000070的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000078的历史数据
# 成功将000078的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000088的历史数据
# 成功将000088的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000089的历史数据
# 成功将000089的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000090的历史数据
# 成功将000090的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000096的历史数据
# 成功将000096的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000099的历史数据
# 成功将000099的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000100的历史数据
# 成功将000100的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000151的历史数据
# 成功将000151的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000153的历史数据
# 成功将000153的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000155的历史数据
# 成功将000155的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000156的历史数据
# 成功将000156的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000157的历史数据
# 成功将000157的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000158的历史数据
# 成功将000158的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000159的历史数据
# 成功将000159的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000166的历史数据
# 成功将000166的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000301的历史数据
# 成功将000301的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000333的历史数据
# 成功将000333的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000338的历史数据
# 成功将000338的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000400的历史数据
# 成功将000400的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000401的历史数据
# 成功将000401的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000402的历史数据
# 成功将000402的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000403的历史数据
# 成功将000403的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000404的历史数据
# 成功将000404的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000407的历史数据
# 成功将000407的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000408的历史数据
# 成功将000408的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000409的历史数据
# 成功将000409的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000410的历史数据
# 成功将000410的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000411的历史数据
# 成功将000411的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-04-30
# 成功获取000413的历史数据
# 成功将000413的历史数据逐条更新或插入到数据库，处理数据条数：1
# 最新日期 :  2024-05-20
# 成功获取000415的历史数据
# 成功将000415的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-04-24
# 成功获取000416的历史数据
# 成功将000416的历史数据逐条更新或插入到数据库，处理数据条数：1
# 最新日期 :  2024-05-20
# 成功获取000417的历史数据
# 成功将000417的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000419的历史数据
# 成功将000419的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000420的历史数据
# 成功将000420的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000421的历史数据
# 成功将000421的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000422的历史数据
# 成功将000422的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000423的历史数据
# 成功将000423的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000425的历史数据
# 成功将000425的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000426的历史数据
# 成功将000426的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000428的历史数据
# 成功将000428的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000429的历史数据
# 成功将000429的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000430的历史数据
# 成功将000430的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000488的历史数据
# 成功将000488的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000498的历史数据
# 成功将000498的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000501的历史数据
# 成功将000501的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000503的历史数据
# 成功将000503的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000504的历史数据
# 成功将000504的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000505的历史数据
# 成功将000505的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000506的历史数据
# 成功将000506的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000507的历史数据
# 成功将000507的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000509的历史数据
# 成功将000509的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000510的历史数据
# 成功将000510的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000513的历史数据
# 成功将000513的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000514的历史数据
# 成功将000514的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000516的历史数据
# 成功将000516的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000517的历史数据
# 成功将000517的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000518的历史数据
# 成功将000518的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000519的历史数据
# 成功将000519的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000520的历史数据
# 成功将000520的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000521的历史数据
# 成功将000521的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000523的历史数据
# 成功将000523的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000524的历史数据
# 成功将000524的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000525的历史数据
# 成功将000525的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000526的历史数据
# 成功将000526的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000528的历史数据
# 成功将000528的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000529的历史数据
# 成功将000529的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000530的历史数据
# 成功将000530的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000531的历史数据
# 成功将000531的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000532的历史数据
# 成功将000532的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000533的历史数据
# 成功将000533的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000534的历史数据
# 成功将000534的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000536的历史数据
# 成功将000536的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000537的历史数据
# 成功将000537的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000538的历史数据
# 成功将000538的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000539的历史数据
# 成功将000539的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000541的历史数据
# 成功将000541的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000543的历史数据
# 成功将000543的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000544的历史数据
# 成功将000544的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000545的历史数据
# 成功将000545的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000546的历史数据
# 成功将000546的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000547的历史数据
# 成功将000547的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000548的历史数据
# 成功将000548的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000550的历史数据
# 成功将000550的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000551的历史数据
# 成功将000551的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000552的历史数据
# 成功将000552的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000553的历史数据
# 成功将000553的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000554的历史数据
# 成功将000554的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000555的历史数据
# 成功将000555的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000557的历史数据
# 成功将000557的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000558的历史数据
# 成功将000558的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000559的历史数据
# 成功将000559的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000560的历史数据
# 成功将000560的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000561的历史数据
# 成功将000561的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000563的历史数据
# 成功将000563的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000564的历史数据
# 成功将000564的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000565的历史数据
# 成功将000565的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000566的历史数据
# 成功将000566的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000567的历史数据
# 成功将000567的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000568的历史数据
# 成功将000568的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000570的历史数据
# 成功将000570的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000571的历史数据
# 成功将000571的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000572的历史数据
# 成功将000572的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000573的历史数据
# 成功将000573的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000576的历史数据
# 成功将000576的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000581的历史数据
# 成功将000581的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000582的历史数据
# 成功将000582的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000584的历史数据
# 成功将000584的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000586的历史数据
# 成功将000586的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000589的历史数据
# 成功将000589的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000590的历史数据
# 成功将000590的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000591的历史数据
# 成功将000591的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000592的历史数据
# 成功将000592的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000593的历史数据
# 成功将000593的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000595的历史数据
# 成功将000595的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000596的历史数据
# 成功将000596的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000597的历史数据
# 成功将000597的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000598的历史数据
# 成功将000598的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000599的历史数据
# 成功将000599的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000600的历史数据
# 成功将000600的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000601的历史数据
# 成功将000601的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000603的历史数据
# 成功将000603的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000605的历史数据
# 成功将000605的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000607的历史数据
# 成功将000607的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000608的历史数据
# 成功将000608的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000609的历史数据
# 成功将000609的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000610的历史数据
# 成功将000610的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000612的历史数据
# 成功将000612的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000615的历史数据
# 成功将000615的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000617的历史数据
# 成功将000617的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000619的历史数据
# 成功将000619的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-17
# 成功获取000620的历史数据
# 成功将000620的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000622的历史数据
# 成功将000622的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000623的历史数据
# 成功将000623的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000625的历史数据
# 成功将000625的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000626的历史数据
# 成功将000626的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000627的历史数据
# 成功将000627的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000628的历史数据
# 成功将000628的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000629的历史数据
# 成功将000629的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000630的历史数据
# 成功将000630的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000631的历史数据
# 成功将000631的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000632的历史数据
# 成功将000632的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000633的历史数据
# 成功将000633的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000635的历史数据
# 成功将000635的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000636的历史数据
# 成功将000636的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000637的历史数据
# 成功将000637的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000638的历史数据
# 成功将000638的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000639的历史数据
# 成功将000639的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000650的历史数据
# 成功将000650的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000651的历史数据
# 成功将000651的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000652的历史数据
# 成功将000652的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000655的历史数据
# 成功将000655的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000656的历史数据
# 成功将000656的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000657的历史数据
# 成功将000657的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000659的历史数据
# 成功将000659的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000661的历史数据
# 成功将000661的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000663的历史数据
# 成功将000663的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000665的历史数据
# 成功将000665的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000668的历史数据
# 成功将000668的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000669的历史数据
# 成功将000669的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000670的历史数据
# 成功将000670的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000672的历史数据
# 成功将000672的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000676的历史数据
# 成功将000676的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000677的历史数据
# 成功将000677的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000678的历史数据
# 成功将000678的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000679的历史数据
# 成功将000679的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000680的历史数据
# 成功将000680的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000681的历史数据
# 成功将000681的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000682的历史数据
# 成功将000682的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000683的历史数据
# 成功将000683的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000685的历史数据
# 成功将000685的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000686的历史数据
# 成功将000686的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000688的历史数据
# 成功将000688的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000690的历史数据
# 成功将000690的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000691的历史数据
# 成功将000691的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000692的历史数据
# 成功将000692的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000695的历史数据
# 成功将000695的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000697的历史数据
# 成功将000697的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000698的历史数据
# 成功将000698的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000700的历史数据
# 成功将000700的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000701的历史数据
# 成功将000701的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000702的历史数据
# 成功将000702的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000703的历史数据
# 成功将000703的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000705的历史数据
# 成功将000705的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000707的历史数据
# 成功将000707的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000708的历史数据
# 成功将000708的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000709的历史数据
# 成功将000709的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000710的历史数据
# 成功将000710的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000711的历史数据
# 成功将000711的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000712的历史数据
# 成功将000712的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000713的历史数据
# 成功将000713的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000715的历史数据
# 成功将000715的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000716的历史数据
# 成功将000716的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000717的历史数据
# 成功将000717的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000718的历史数据
# 成功将000718的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000719的历史数据
# 成功将000719的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000720的历史数据
# 成功将000720的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000721的历史数据
# 成功将000721的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000722的历史数据
# 成功将000722的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000723的历史数据
# 成功将000723的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000725的历史数据
# 成功将000725的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000726的历史数据
# 成功将000726的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000727的历史数据
# 成功将000727的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000728的历史数据
# 成功将000728的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000729的历史数据
# 成功将000729的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000731的历史数据
# 成功将000731的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000733的历史数据
# 成功将000733的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000735的历史数据
# 成功将000735的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000736的历史数据
# 成功将000736的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000737的历史数据
# 成功将000737的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000738的历史数据
# 成功将000738的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000739的历史数据
# 成功将000739的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000750的历史数据
# 成功将000750的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000751的历史数据
# 成功将000751的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000752的历史数据
# 成功将000752的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000753的历史数据
# 成功将000753的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000755的历史数据
# 成功将000755的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000756的历史数据
# 成功将000756的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000757的历史数据
# 成功将000757的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000758的历史数据
# 成功将000758的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000759的历史数据
# 成功将000759的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000761的历史数据
# 成功将000761的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000762的历史数据
# 成功将000762的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000766的历史数据
# 成功将000766的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000767的历史数据
# 成功将000767的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000768的历史数据
# 成功将000768的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000776的历史数据
# 成功将000776的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000777的历史数据
# 成功将000777的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000778的历史数据
# 成功将000778的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000779的历史数据
# 成功将000779的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000782的历史数据
# 成功将000782的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000783的历史数据
# 成功将000783的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000785的历史数据
# 成功将000785的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000786的历史数据
# 成功将000786的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000788的历史数据
# 成功将000788的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000789的历史数据
# 成功将000789的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000790的历史数据
# 成功将000790的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000791的历史数据
# 成功将000791的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000792的历史数据
# 成功将000792的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000793的历史数据
# 成功将000793的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000795的历史数据
# 成功将000795的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000796的历史数据
# 成功将000796的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000797的历史数据
# 成功将000797的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000798的历史数据
# 成功将000798的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000799的历史数据
# 成功将000799的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000800的历史数据
# 成功将000800的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000801的历史数据
# 成功将000801的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000802的历史数据
# 成功将000802的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000803的历史数据
# 成功将000803的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000807的历史数据
# 成功将000807的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000809的历史数据
# 成功将000809的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000810的历史数据
# 成功将000810的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000811的历史数据
# 成功将000811的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000812的历史数据
# 成功将000812的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000813的历史数据
# 成功将000813的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000815的历史数据
# 成功将000815的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000816的历史数据
# 成功将000816的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000818的历史数据
# 成功将000818的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000819的历史数据
# 成功将000819的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000820的历史数据
# 成功将000820的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000821的历史数据
# 成功将000821的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000822的历史数据
# 成功将000822的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000823的历史数据
# 成功将000823的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000825的历史数据
# 成功将000825的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000826的历史数据
# 成功将000826的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000828的历史数据
# 成功将000828的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000829的历史数据
# 成功将000829的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000830的历史数据
# 成功将000830的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000831的历史数据
# 成功将000831的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000833的历史数据
# 成功将000833的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000836的历史数据
# 成功将000836的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000837的历史数据
# 成功将000837的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000838的历史数据
# 成功将000838的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000839的历史数据
# 成功将000839的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000848的历史数据
# 成功将000848的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000850的历史数据
# 成功将000850的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000851的历史数据
# 成功将000851的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000852的历史数据
# 成功将000852的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000856的历史数据
# 成功将000856的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000858的历史数据
# 成功将000858的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000859的历史数据
# 成功将000859的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000860的历史数据
# 成功将000860的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000861的历史数据
# 成功将000861的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000862的历史数据
# 成功将000862的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000863的历史数据
# 成功将000863的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000868的历史数据
# 成功将000868的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000869的历史数据
# 成功将000869的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000875的历史数据
# 成功将000875的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000876的历史数据
# 成功将000876的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000877的历史数据
# 成功将000877的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000878的历史数据
# 成功将000878的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000880的历史数据
# 成功将000880的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000881的历史数据
# 成功将000881的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000882的历史数据
# 成功将000882的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000883的历史数据
# 成功将000883的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000885的历史数据
# 成功将000885的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000886的历史数据
# 成功将000886的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000887的历史数据
# 成功将000887的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000888的历史数据
# 成功将000888的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000889的历史数据
# 成功将000889的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000890的历史数据
# 成功将000890的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000892的历史数据
# 成功将000892的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000893的历史数据
# 成功将000893的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000895的历史数据
# 成功将000895的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000897的历史数据
# 成功将000897的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000898的历史数据
# 成功将000898的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000899的历史数据
# 成功将000899的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000900的历史数据
# 成功将000900的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000901的历史数据
# 成功将000901的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000902的历史数据
# 成功将000902的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000903的历史数据
# 成功将000903的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000905的历史数据
# 成功将000905的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000906的历史数据
# 成功将000906的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000908的历史数据
# 成功将000908的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000909的历史数据
# 成功将000909的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000910的历史数据
# 成功将000910的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000911的历史数据
# 成功将000911的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000912的历史数据
# 成功将000912的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000913的历史数据
# 成功将000913的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000915的历史数据
# 成功将000915的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000917的历史数据
# 成功将000917的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000919的历史数据
# 成功将000919的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000920的历史数据
# 成功将000920的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000921的历史数据
# 成功将000921的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000922的历史数据
# 成功将000922的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000923的历史数据
# 成功将000923的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000925的历史数据
# 成功将000925的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000926的历史数据
# 成功将000926的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000927的历史数据
# 成功将000927的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000928的历史数据
# 成功将000928的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000929的历史数据
# 成功将000929的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000930的历史数据
# 成功将000930的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000931的历史数据
# 成功将000931的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000932的历史数据
# 成功将000932的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000933的历史数据
# 成功将000933的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000935的历史数据
# 成功将000935的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000936的历史数据
# 成功将000936的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000937的历史数据
# 成功将000937的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000938的历史数据
# 成功将000938的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000948的历史数据
# 成功将000948的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000949的历史数据
# 成功将000949的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000950的历史数据
# 成功将000950的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000951的历史数据
# 成功将000951的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000952的历史数据
# 成功将000952的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000953的历史数据
# 成功将000953的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000955的历史数据
# 成功将000955的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000957的历史数据
# 成功将000957的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000958的历史数据
# 成功将000958的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000959的历史数据
# 成功将000959的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000960的历史数据
# 成功将000960的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-08
# 成功获取000961的历史数据
# 成功将000961的历史数据逐条更新或插入到数据库，处理数据条数：1
# 最新日期 :  2024-05-20
# 成功获取000962的历史数据
# 成功将000962的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000963的历史数据
# 成功将000963的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000965的历史数据
# 成功将000965的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000966的历史数据
# 成功将000966的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000967的历史数据
# 成功将000967的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000968的历史数据
# 成功将000968的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000969的历史数据
# 成功将000969的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000970的历史数据
# 成功将000970的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000971的历史数据
# 成功将000971的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000972的历史数据
# 成功将000972的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000973的历史数据
# 成功将000973的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000975的历史数据
# 成功将000975的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-04-30
# 成功获取000976的历史数据
# 成功将000976的历史数据逐条更新或插入到数据库，处理数据条数：1
# 最新日期 :  2024-05-20
# 成功获取000977的历史数据
# 成功将000977的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000978的历史数据
# 成功将000978的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000980的历史数据
# 成功将000980的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000981的历史数据
# 成功将000981的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000982的历史数据
# 成功将000982的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000983的历史数据
# 成功将000983的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000985的历史数据
# 成功将000985的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000987的历史数据
# 成功将000987的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000988的历史数据
# 成功将000988的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000989的历史数据
# 成功将000989的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000990的历史数据
# 成功将000990的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000993的历史数据
# 成功将000993的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000995的历史数据
# 成功将000995的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-04-29
# 成功获取000996的历史数据
# 成功将000996的历史数据逐条更新或插入到数据库，处理数据条数：1
# 最新日期 :  2024-05-20
# 成功获取000997的历史数据
# 成功将000997的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000998的历史数据
# 成功将000998的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取000999的历史数据
# 成功将000999的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001201的历史数据
# 成功将001201的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001202的历史数据
# 成功将001202的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001203的历史数据
# 成功将001203的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001205的历史数据
# 成功将001205的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001206的历史数据
# 成功将001206的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001207的历史数据
# 成功将001207的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001208的历史数据
# 成功将001208的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001209的历史数据
# 成功将001209的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001210的历史数据
# 成功将001210的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001211的历史数据
# 成功将001211的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001212的历史数据
# 成功将001212的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001213的历史数据
# 成功将001213的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001215的历史数据
# 成功将001215的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001216的历史数据
# 成功将001216的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001217的历史数据
# 成功将001217的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001218的历史数据
# 成功将001218的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001219的历史数据
# 成功将001219的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001222的历史数据
# 成功将001222的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001223的历史数据
# 成功将001223的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001225的历史数据
# 成功将001225的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001226的历史数据
# 成功将001226的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001227的历史数据
# 成功将001227的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001228的历史数据
# 成功将001228的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001229的历史数据
# 成功将001229的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001230的历史数据
# 成功将001230的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001231的历史数据
# 成功将001231的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001234的历史数据
# 成功将001234的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001236的历史数据
# 成功将001236的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001238的历史数据
# 成功将001238的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001239的历史数据
# 成功将001239的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001255的历史数据
# 成功将001255的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001256的历史数据
# 成功将001256的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001258的历史数据
# 成功将001258的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001259的历史数据
# 成功将001259的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001260的历史数据
# 成功将001260的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001266的历史数据
# 成功将001266的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001267的历史数据
# 成功将001267的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001268的历史数据
# 成功将001268的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001269的历史数据
# 成功将001269的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001270的历史数据
# 成功将001270的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001278的历史数据
# 成功将001278的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001282的历史数据
# 成功将001282的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001283的历史数据
# 成功将001283的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001286的历史数据
# 成功将001286的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001287的历史数据
# 成功将001287的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001288的历史数据
# 成功将001288的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001289的历史数据
# 成功将001289的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001296的历史数据
# 成功将001296的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001298的历史数据
# 成功将001298的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001299的历史数据
# 成功将001299的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001300的历史数据
# 成功将001300的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001301的历史数据
# 成功将001301的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001306的历史数据
# 成功将001306的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001308的历史数据
# 成功将001308的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001309的历史数据
# 成功将001309的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001311的历史数据
# 成功将001311的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001313的历史数据
# 成功将001313的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001314的历史数据
# 成功将001314的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001316的历史数据
# 成功将001316的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001317的历史数据
# 成功将001317的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001318的历史数据
# 成功将001318的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001319的历史数据
# 成功将001319的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001322的历史数据
# 成功将001322的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001323的历史数据
# 成功将001323的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001324的历史数据
# 成功将001324的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001326的历史数据
# 成功将001326的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001328的历史数据
# 成功将001328的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001330的历史数据
# 成功将001330的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001331的历史数据
# 成功将001331的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001332的历史数据
# 成功将001332的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001333的历史数据
# 成功将001333的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001336的历史数据
# 成功将001336的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001337的历史数据
# 成功将001337的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001338的历史数据
# 成功将001338的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001339的历史数据
# 成功将001339的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001358的历史数据
# 成功将001358的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001359的历史数据
# 成功将001359的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001360的历史数据
# 成功将001360的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001366的历史数据
# 成功将001366的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001367的历史数据
# 成功将001367的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001368的历史数据
# 成功将001368的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001373的历史数据
# 成功将001373的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001376的历史数据
# 成功将001376的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001378的历史数据
# 成功将001378的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001379的历史数据
# 成功将001379的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001380的历史数据
# 成功将001380的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001387的历史数据
# 成功将001387的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001389的历史数据
# 成功将001389的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001696的历史数据
# 成功将001696的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001872的历史数据
# 成功将001872的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001896的历史数据
# 成功将001896的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001914的历史数据
# 成功将001914的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001965的历史数据
# 成功将001965的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取001979的历史数据
# 成功将001979的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002001的历史数据
# 成功将002001的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002003的历史数据
# 成功将002003的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002004的历史数据
# 成功将002004的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002005的历史数据
# 成功将002005的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002006的历史数据
# 成功将002006的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002007的历史数据
# 成功将002007的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002008的历史数据
# 成功将002008的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002009的历史数据
# 成功将002009的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002010的历史数据
# 成功将002010的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002011的历史数据
# 成功将002011的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002012的历史数据
# 成功将002012的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002014的历史数据
# 成功将002014的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002015的历史数据
# 成功将002015的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002016的历史数据
# 成功将002016的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002017的历史数据
# 成功将002017的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002019的历史数据
# 成功将002019的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002020的历史数据
# 成功将002020的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002021的历史数据
# 成功将002021的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002022的历史数据
# 成功将002022的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002023的历史数据
# 成功将002023的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002024的历史数据
# 成功将002024的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002025的历史数据
# 成功将002025的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002026的历史数据
# 成功将002026的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002027的历史数据
# 成功将002027的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002028的历史数据
# 成功将002028的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002029的历史数据
# 成功将002029的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002030的历史数据
# 成功将002030的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002031的历史数据
# 成功将002031的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002032的历史数据
# 成功将002032的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002033的历史数据
# 成功将002033的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002034的历史数据
# 成功将002034的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002035的历史数据
# 成功将002035的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002036的历史数据
# 成功将002036的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002037的历史数据
# 成功将002037的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002038的历史数据
# 成功将002038的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002039的历史数据
# 成功将002039的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002040的历史数据
# 成功将002040的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002041的历史数据
# 成功将002041的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002042的历史数据
# 成功将002042的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002043的历史数据
# 成功将002043的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002044的历史数据
# 成功将002044的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002045的历史数据
# 成功将002045的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002046的历史数据
# 成功将002046的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002047的历史数据
# 成功将002047的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002048的历史数据
# 成功将002048的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002049的历史数据
# 成功将002049的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002050的历史数据
# 成功将002050的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002051的历史数据
# 成功将002051的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002052的历史数据
# 成功将002052的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002053的历史数据
# 成功将002053的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002054的历史数据
# 成功将002054的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002055的历史数据
# 成功将002055的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002056的历史数据
# 成功将002056的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002057的历史数据
# 成功将002057的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002058的历史数据
# 成功将002058的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002059的历史数据
# 成功将002059的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002060的历史数据
# 成功将002060的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002061的历史数据
# 成功将002061的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002062的历史数据
# 成功将002062的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002063的历史数据
# 成功将002063的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002064的历史数据
# 成功将002064的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002065的历史数据
# 成功将002065的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002066的历史数据
# 成功将002066的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002067的历史数据
# 成功将002067的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002068的历史数据
# 成功将002068的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002069的历史数据
# 成功将002069的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002072的历史数据
# 成功将002072的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002073的历史数据
# 成功将002073的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002074的历史数据
# 成功将002074的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002075的历史数据
# 成功将002075的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002076的历史数据
# 成功将002076的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002077的历史数据
# 成功将002077的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002078的历史数据
# 成功将002078的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002079的历史数据
# 成功将002079的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002080的历史数据
# 成功将002080的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002081的历史数据
# 成功将002081的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002082的历史数据
# 成功将002082的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002083的历史数据
# 成功将002083的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002084的历史数据
# 成功将002084的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002085的历史数据
# 成功将002085的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002086的历史数据
# 成功将002086的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-04-29
# 成功获取002087的历史数据
# 成功将002087的历史数据逐条更新或插入到数据库，处理数据条数：1
# 最新日期 :  2024-05-20
# 成功获取002088的历史数据
# 成功将002088的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002090的历史数据
# 成功将002090的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002091的历史数据
# 成功将002091的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-17
# 成功获取002092的历史数据
# 成功将002092的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002093的历史数据
# 成功将002093的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002094的历史数据
# 成功将002094的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002095的历史数据
# 成功将002095的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002096的历史数据
# 成功将002096的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002097的历史数据
# 成功将002097的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002098的历史数据
# 成功将002098的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002099的历史数据
# 成功将002099的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002100的历史数据
# 成功将002100的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002101的历史数据
# 成功将002101的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002102的历史数据
# 成功将002102的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002103的历史数据
# 成功将002103的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002104的历史数据
# 成功将002104的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002105的历史数据
# 成功将002105的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002106的历史数据
# 成功将002106的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002107的历史数据
# 成功将002107的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002108的历史数据
# 成功将002108的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002109的历史数据
# 成功将002109的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002110的历史数据
# 成功将002110的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002111的历史数据
# 成功将002111的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002112的历史数据
# 成功将002112的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002114的历史数据
# 成功将002114的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002115的历史数据
# 成功将002115的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002116的历史数据
# 成功将002116的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002117的历史数据
# 成功将002117的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002119的历史数据
# 成功将002119的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002120的历史数据
# 成功将002120的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002121的历史数据
# 成功将002121的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002122的历史数据
# 成功将002122的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002123的历史数据
# 成功将002123的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002124的历史数据
# 成功将002124的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002125的历史数据
# 成功将002125的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002126的历史数据
# 成功将002126的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002127的历史数据
# 成功将002127的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002128的历史数据
# 成功将002128的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002129的历史数据
# 成功将002129的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002130的历史数据
# 成功将002130的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002131的历史数据
# 成功将002131的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002132的历史数据
# 成功将002132的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002133的历史数据
# 成功将002133的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002134的历史数据
# 成功将002134的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002135的历史数据
# 成功将002135的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002136的历史数据
# 成功将002136的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002137的历史数据
# 成功将002137的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002138的历史数据
# 成功将002138的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002139的历史数据
# 成功将002139的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002140的历史数据
# 成功将002140的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002141的历史数据
# 成功将002141的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002142的历史数据
# 成功将002142的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002144的历史数据
# 成功将002144的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002145的历史数据
# 成功将002145的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002146的历史数据
# 成功将002146的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002148的历史数据
# 成功将002148的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002149的历史数据
# 成功将002149的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002150的历史数据
# 成功将002150的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002151的历史数据
# 成功将002151的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002152的历史数据
# 成功将002152的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002153的历史数据
# 成功将002153的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002154的历史数据
# 成功将002154的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002155的历史数据
# 成功将002155的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002156的历史数据
# 成功将002156的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002157的历史数据
# 成功将002157的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002158的历史数据
# 成功将002158的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002159的历史数据
# 成功将002159的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002160的历史数据
# 成功将002160的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002161的历史数据
# 成功将002161的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002162的历史数据
# 成功将002162的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002163的历史数据
# 成功将002163的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002164的历史数据
# 成功将002164的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002165的历史数据
# 成功将002165的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002166的历史数据
# 成功将002166的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002167的历史数据
# 成功将002167的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002168的历史数据
# 成功将002168的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002169的历史数据
# 成功将002169的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002170的历史数据
# 成功将002170的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002171的历史数据
# 成功将002171的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002172的历史数据
# 成功将002172的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取002173的历史数据
# 成功将002173的历史数据逐条更新或插入到数据库，处理数据条数：2
# ...
# 成功将830832的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取830839的历史数据
# 成功将830839的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取830879的历史数据
# 成功将830879的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取830896的历史数据
# 成功将830896的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取830946的历史数据
# 成功将830946的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取830964的历史数据
# 成功将830964的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取830974的历史数据
# 成功将830974的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831010的历史数据
# 成功将831010的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831039的历史数据
# 成功将831039的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831087的历史数据
# 成功将831087的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831152的历史数据
# 成功将831152的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831167的历史数据
# 成功将831167的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831175的历史数据
# 成功将831175的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831195的历史数据
# 成功将831195的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831278的历史数据
# 成功将831278的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831304的历史数据
# 成功将831304的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831305的历史数据
# 成功将831305的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831370的历史数据
# 成功将831370的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831396的历史数据
# 成功将831396的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831445的历史数据
# 成功将831445的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831526的历史数据
# 成功将831526的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831627的历史数据
# 成功将831627的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831641的历史数据
# 成功将831641的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831689的历史数据
# 成功将831689的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831726的历史数据
# 成功将831726的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831768的历史数据
# 成功将831768的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831832的历史数据
# 成功将831832的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831834的历史数据
# 成功将831834的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831855的历史数据
# 成功将831855的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831856的历史数据
# 成功将831856的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831906的历史数据
# 成功将831906的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取831961的历史数据
# 成功将831961的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832000的历史数据
# 成功将832000的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832023的历史数据
# 成功将832023的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832089的历史数据
# 成功将832089的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832110的历史数据
# 成功将832110的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832145的历史数据
# 成功将832145的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832149的历史数据
# 成功将832149的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832171的历史数据
# 成功将832171的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832175的历史数据
# 成功将832175的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832225的历史数据
# 成功将832225的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832278的历史数据
# 成功将832278的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832419的历史数据
# 成功将832419的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832469的历史数据
# 成功将832469的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832471的历史数据
# 成功将832471的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832491的历史数据
# 成功将832491的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832522的历史数据
# 成功将832522的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832566的历史数据
# 成功将832566的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832651的历史数据
# 成功将832651的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832662的历史数据
# 成功将832662的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832735的历史数据
# 成功将832735的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832786的历史数据
# 成功将832786的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832802的历史数据
# 成功将832802的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832876的历史数据
# 成功将832876的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832885的历史数据
# 成功将832885的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832978的历史数据
# 成功将832978的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取832982的历史数据
# 成功将832982的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833030的历史数据
# 成功将833030的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833075的历史数据
# 成功将833075的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833171的历史数据
# 成功将833171的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833230的历史数据
# 成功将833230的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833266的历史数据
# 成功将833266的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833284的历史数据
# 成功将833284的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833346的历史数据
# 成功将833346的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833394的历史数据
# 成功将833394的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833427的历史数据
# 成功将833427的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833429的历史数据
# 成功将833429的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833454的历史数据
# 成功将833454的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833455的历史数据
# 成功将833455的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833509的历史数据
# 成功将833509的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833523的历史数据
# 成功将833523的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833533的历史数据
# 成功将833533的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833575的历史数据
# 成功将833575的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833580的历史数据
# 成功将833580的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833751的历史数据
# 成功将833751的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833781的历史数据
# 成功将833781的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833819的历史数据
# 成功将833819的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833873的历史数据
# 成功将833873的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833914的历史数据
# 成功将833914的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取833943的历史数据
# 成功将833943的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取834014的历史数据
# 成功将834014的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取834021的历史数据
# 成功将834021的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取834033的历史数据
# 成功将834033的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取834058的历史数据
# 成功将834058的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取834062的历史数据
# 成功将834062的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取834261的历史数据
# 成功将834261的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取834407的历史数据
# 成功将834407的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取834415的历史数据
# 成功将834415的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取834475的历史数据
# 成功将834475的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取834599的历史数据
# 成功将834599的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取834639的历史数据
# 成功将834639的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取834682的历史数据
# 成功将834682的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取834765的历史数据
# 成功将834765的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取834770的历史数据
# 成功将834770的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取834950的历史数据
# 成功将834950的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取835174的历史数据
# 成功将835174的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取835179的历史数据
# 成功将835179的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取835184的历史数据
# 成功将835184的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取835185的历史数据
# 成功将835185的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取835207的历史数据
# 成功将835207的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取835237的历史数据
# 成功将835237的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取835305的历史数据
# 成功将835305的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取835368的历史数据
# 成功将835368的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取835438的历史数据
# 成功将835438的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取835508的历史数据
# 成功将835508的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取835579的历史数据
# 成功将835579的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取835640的历史数据
# 成功将835640的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取835670的历史数据
# 成功将835670的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取835857的历史数据
# 成功将835857的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取835892的历史数据
# 成功将835892的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取835985的历史数据
# 成功将835985的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836077的历史数据
# 成功将836077的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836149的历史数据
# 成功将836149的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836208的历史数据
# 成功将836208的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836221的历史数据
# 成功将836221的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836239的历史数据
# 成功将836239的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836247的历史数据
# 成功将836247的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836260的历史数据
# 成功将836260的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836263的历史数据
# 成功将836263的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836270的历史数据
# 成功将836270的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836395的历史数据
# 成功将836395的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836414的历史数据
# 成功将836414的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836419的历史数据
# 成功将836419的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836422的历史数据
# 成功将836422的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836433的历史数据
# 成功将836433的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836504的历史数据
# 成功将836504的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836547的历史数据
# 成功将836547的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836675的历史数据
# 成功将836675的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836699的历史数据
# 成功将836699的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836717的历史数据
# 成功将836717的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836720的历史数据
# 成功将836720的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836807的历史数据
# 成功将836807的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836826的历史数据
# 成功将836826的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836871的历史数据
# 成功将836871的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836892的历史数据
# 成功将836892的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836942的历史数据
# 成功将836942的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836957的历史数据
# 成功将836957的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取836961的历史数据
# 成功将836961的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取837006的历史数据
# 成功将837006的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取837023的历史数据
# 成功将837023的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取837046的历史数据
# 成功将837046的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取837092的历史数据
# 成功将837092的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取837174的历史数据
# 成功将837174的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取837212的历史数据
# 成功将837212的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取837242的历史数据
# 成功将837242的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取837344的历史数据
# 成功将837344的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取837403的历史数据
# 成功将837403的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取837592的历史数据
# 成功将837592的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取837663的历史数据
# 成功将837663的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取837748的历史数据
# 成功将837748的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取837821的历史数据
# 成功将837821的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取838030的历史数据
# 成功将838030的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取838163的历史数据
# 成功将838163的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取838171的历史数据
# 成功将838171的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取838227的历史数据
# 成功将838227的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取838262的历史数据
# 成功将838262的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取838275的历史数据
# 成功将838275的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取838402的历史数据
# 成功将838402的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取838670的历史数据
# 成功将838670的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取838701的历史数据
# 成功将838701的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取838810的历史数据
# 成功将838810的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取838837的历史数据
# 成功将838837的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取838924的历史数据
# 成功将838924的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取838971的历史数据
# 成功将838971的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取839167的历史数据
# 成功将839167的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取839273的历史数据
# 成功将839273的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取839371的历史数据
# 成功将839371的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取839493的历史数据
# 成功将839493的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取839680的历史数据
# 成功将839680的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取839719的历史数据
# 成功将839719的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取839725的历史数据
# 成功将839725的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取839729的历史数据
# 成功将839729的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取839790的历史数据
# 成功将839790的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取839792的历史数据
# 成功将839792的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取839946的历史数据
# 成功将839946的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取870199的历史数据
# 成功将870199的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取870204的历史数据
# 成功将870204的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取870299的历史数据
# 成功将870299的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取870357的历史数据
# 成功将870357的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取870436的历史数据
# 成功将870436的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取870508的历史数据
# 成功将870508的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取870656的历史数据
# 成功将870656的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取870726的历史数据
# 成功将870726的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取870866的历史数据
# 成功将870866的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取870976的历史数据
# 成功将870976的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取871245的历史数据
# 成功将871245的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取871263的历史数据
# 成功将871263的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取871396的历史数据
# 成功将871396的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取871478的历史数据
# 成功将871478的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取871553的历史数据
# 成功将871553的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取871634的历史数据
# 成功将871634的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取871642的历史数据
# 成功将871642的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取871694的历史数据
# 成功将871694的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取871753的历史数据
# 成功将871753的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取871857的历史数据
# 成功将871857的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取871970的历史数据
# 成功将871970的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取871981的历史数据
# 成功将871981的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取872190的历史数据
# 成功将872190的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取872351的历史数据
# 成功将872351的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取872374的历史数据
# 成功将872374的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取872392的历史数据
# 成功将872392的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取872541的历史数据
# 成功将872541的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取872808的历史数据
# 成功将872808的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取872895的历史数据
# 成功将872895的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取872925的历史数据
# 成功将872925的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取872931的历史数据
# 成功将872931的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取872953的历史数据
# 成功将872953的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873001的历史数据
# 成功将873001的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873122的历史数据
# 成功将873122的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873132的历史数据
# 成功将873132的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873152的历史数据
# 成功将873152的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873167的历史数据
# 成功将873167的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873169的历史数据
# 成功将873169的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873223的历史数据
# 成功将873223的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873305的历史数据
# 成功将873305的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873339的历史数据
# 成功将873339的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873527的历史数据
# 成功将873527的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873570的历史数据
# 成功将873570的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873576的历史数据
# 成功将873576的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873593的历史数据
# 成功将873593的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873665的历史数据
# 成功将873665的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873679的历史数据
# 成功将873679的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873690的历史数据
# 成功将873690的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873693的历史数据
# 成功将873693的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873703的历史数据
# 成功将873703的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873706的历史数据
# 成功将873706的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873726的历史数据
# 成功将873726的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873806的历史数据
# 成功将873806的历史数据逐条更新或插入到数据库，处理数据条数：2
# 最新日期 :  2024-05-20
# 成功获取873833的历史数据
# 成功将873833的历史数据逐条更新或插入到数据库，处理数据条数：2

# %%
# Import the necessary module for StockAnalysisTool
import time
import pandas as pd
from StockAnalysisTool import StockAnalysisTool

# Create an instance of StockAnalysisTool with a global timestamp
global_timestamp = time.strftime("%Y-%m-%d_%H-%M-%S")
tool = StockAnalysisTool("000420", global_timestamp)


# Check for MACD crossover on 2024-05-17
macd_crossover_occurred = tool.check_macd_crossover(pd.Timestamp('2024-05-17'))
print(f"MACD Crossover on 2024-05-17 for stock 000420.SZ: {macd_crossover_occurred}")

# Define variables for date and number of days
crossover_date = '2024-05-20'
days_before = 3
# Check for recent MACD crossover within 3 days before 2024-05-20
recent_macd_crossover_date = tool.find_recent_macd_crossover(crossover_date, days_before)
if recent_macd_crossover_date:
    print(f"Recent MACD Crossover occurred on: {recent_macd_crossover_date}")
else:
    print(f"No recent MACD Crossover within {days_before} days before {crossover_date}")


print(f"\n")

# Check for volume crossover on 2024-05-17
volume_crossover_occurredr_5_over_10 = tool.check_volume_crossover_5_over_10(pd.Timestamp('2024-05-16'))
print(f"volume Crossover 5_over_10 on 2024-05-16 for stock 000420.SZ: {volume_crossover_occurredr_5_over_10}")

# Define variables for date and number of days
crossover_date = '2024-05-20'
days_before = 4
# Check for recent volume crossover within 3 days before 2024-05-20
recent_volume_crossover_5_over_10_date = tool.find_recent_volume_crossover_5_over_10(crossover_date, days_before)
if recent_volume_crossover_5_over_10_date:
    print(f"Recent volume Crossover(5_over_10) occurred on: {recent_volume_crossover_5_over_10_date}")
else:
    print(f"No recent volume Crossover(5_over_10) within {days_before} days before {crossover_date}")

print(f"\n")

# Check for price above middle bollinger band on 2024-05-20
price_above_bollinger_middle_band = tool.check_price_above_upper_bollinger_band(pd.Timestamp('2024-05-20'))
print(f"price above middle bollinger band on 2024-05-20 for stock 000420.SZ: {price_above_bollinger_middle_band}")

# Define variables for date and number of days
crossover_date = '2024-05-21'
days_before = 3
# Check for recent price above middle bollinger band within 3 days before 2024-05-20
recent_price_above_bollinger_middle_band = tool.find_recent_price_above_middle_bollinger_band(crossover_date, days_before)
if recent_price_above_bollinger_middle_band:
    print(f"Recent price above middle bollinger band occurred on: {recent_price_above_bollinger_middle_band}")
else:
    print(f"No recent price above middle bollinger band within {days_before} days before {crossover_date}")

print(f"\n")

# Check for KDJ crossover on 2024-05-17
kdj_crossover_occurred = tool.check_kdj_crossover(pd.Timestamp('2024-05-16'))
print(f"KDJ Crossover on 2024-05-16 for stock 000420.SZ: {kdj_crossover_occurred}")

# Define variables for date and number of days
crossover_date = '2024-05-20'
days_before = 4
# Check for recent MACD crossover within 3 days before 2024-05-20
recent_kdj_crossover_date = tool.find_recent_kdj_crossover(crossover_date, days_before)
if recent_kdj_crossover_date:
    print(f"Recent KDJ Crossover occurred on: {recent_kdj_crossover_date}")
else:
    print(f"No recent KDJ Crossover within {days_before} days before {crossover_date}")


# Release resources
del tool

# %%
import time
import sys
import pandas as pd
from tqdm.notebook import tqdm  # Changed from tqdm to tqdm.notebook for Jupyter Notebook compatibility
from sqlalchemy import create_engine, text
from StockAnalysisTool import StockAnalysisTool

# Setup for console output
global_timestamp = time.strftime("%Y-%m-%d_%H-%M-%S")

# Setup for console output redirection
log_filename = f"logs/M_V_B_K_signal_hunter_{time.strftime('%Y%m%d')}.log"
# sys.stdout = open(log_filename, 'a')
# sys.stderr = open(log_filename, 'a')

mining_date = '2024-05-21'
specified_date = '2024-05-21'

# Connect to the database
engine = create_engine('mysql+pymysql://stock:Abcd1234!!@192.168.3.17:3306/aistock')
query = f"SELECT id, stockCode FROM goldencross WHERE miningDate = '{mining_date}'"
stock_codes = pd.read_sql(query, engine)

# Clear the mvbkSignal and mvbkHuntingDate fields for records with the current miningDate
clear_query = text("UPDATE goldencross SET mvbkSignal = NULL, mvbkHuntingDate = NULL, jAtHuntingDate = NULL WHERE miningDate = :mining_date")
with engine.connect() as connection:
    connection.execute(clear_query, {'mining_date': mining_date})
    connection.commit()

try:
    # Ensure tqdm gets the total count by passing the length of the DataFrame
    for index, row in tqdm(stock_codes.iterrows(), total=stock_codes.shape[0], desc="Analyzing Stocks", file=sys.stdout):  # Changed file=sys.stdout to ensure tqdm output and other prints go to the log file
        stock_code = row['stockCode']
        stock_id = row['id']
        # Remove the '.SZ' or '.SH' suffix from the stock code
        formatted_stock_code = stock_code.rstrip('.SZ').rstrip('.SH')
        tool = StockAnalysisTool(formatted_stock_code, global_timestamp)  # Create an instance of StockAnalysisTool for each stock code
        
        # Redirecting print statements to log file
        original_stdout = sys.stdout  # Save a reference to the original standard output
        with open(log_filename, 'a') as f:
            # sys.stdout = f  # Change the standard output to the file we created.
            print(f"Analyzing stock code: {formatted_stock_code}")

            # Check conditions for the stock
            days_back = 2
            macd_crossover = 1 if tool.find_recent_macd_crossover(specified_date, days_back) else 0
            price_cross_ma5 = 1 if tool.find_recent_price_cross_ma5(specified_date, days_back) else 0
            price_above_bollinger = 1 if tool.find_recent_price_above_middle_bollinger_band(specified_date, days_back) else 0
            kdj_crossover = 1 if tool.find_recent_kdj_cross(specified_date, days_back) else 0
            # Count the number of conditions met
            conditions_met = sum([macd_crossover, price_cross_ma5, price_above_bollinger, kdj_crossover])

            if conditions_met == 4:
                print(f"Stock {formatted_stock_code} meets all criteria on {specified_date}")
                update_query = text("UPDATE goldencross SET mvbkSignal = true, mvbkHuntingDate = :specified_date WHERE id = :stock_id")
                with engine.connect() as connection:
                    connection.execute(update_query, {'stock_id': stock_id, 'specified_date': specified_date})
                    connection.commit()
        # sys.stdout = original_stdout  # Reset the standard output to its original value
        del tool  # Release the tool instance after processing each stock

finally:
    # Release resources
    engine.dispose()
    # sys.stdout.close()
    # sys.stderr.close()
# Out:
# Analyzing Stocks:   0%|          | 0/3199 [00:00<?, ?it/s]
# Analyzing stock code: 000001
# Analyzing stock code: 000002
# Analyzing stock code: 000004
# Analyzing stock code: 000006
# Analyzing stock code: 000007
# Analyzing stock code: 000008
# Analyzing stock code: 000009
# Analyzing stock code: 000010
# Analyzing stock code: 000011
# Analyzing stock code: 000012
# Analyzing stock code: 000014
# Analyzing stock code: 000016
# Analyzing stock code: 000017
# Analyzing stock code: 000019
# Analyzing stock code: 000020
# Analyzing stock code: 000021
# Analyzing stock code: 600038
# Analyzing stock code: 600039
# Analyzing stock code: 600048
# Analyzing stock code: 600050
# Analyzing stock code: 600051
# Analyzing stock code: 600052
# Analyzing stock code: 600053
# Analyzing stock code: 600054
# Analyzing stock code: 600055
# Analyzing stock code: 600056
# Analyzing stock code: 600057
# Analyzing stock code: 600058
# Analyzing stock code: 600059
# Analyzing stock code: 600060
# Analyzing stock code: 600061
# Analyzing stock code: 600062
# Analyzing stock code: 600063
# Analyzing stock code: 600064
# Analyzing stock code: 600066
# Analyzing stock code: 600067
# Analyzing stock code: 600070
# Analyzing stock code: 600071
# Analyzing stock code: 600072
# Analyzing stock code: 600073
# Analyzing stock code: 600075
# Analyzing stock code: 600076
# Analyzing stock code: 600078
# Analyzing stock code: 600079
# Analyzing stock code: 600080
# Analyzing stock code: 600081
# Analyzing stock code: 600082
# Analyzing stock code: 600083
# Analyzing stock code: 600084
# Analyzing stock code: 600085
# Analyzing stock code: 600088
# Analyzing stock code: 600089
# Analyzing stock code: 600094
# Analyzing stock code: 600095
# Analyzing stock code: 600096
# Analyzing stock code: 600097
# Analyzing stock code: 600098
# Analyzing stock code: 600099
# Analyzing stock code: 600100
# Analyzing stock code: 600101
# Analyzing stock code: 600103
# Analyzing stock code: 600104
# Analyzing stock code: 600105
# Analyzing stock code: 600106
# Analyzing stock code: 600107
# Analyzing stock code: 600108
# Analyzing stock code: 600109
# Analyzing stock code: 600110
# Analyzing stock code: 600111
# Analyzing stock code: 600112
# Analyzing stock code: 600113
# Analyzing stock code: 600114
# Analyzing stock code: 600115
# Analyzing stock code: 600116
# Analyzing stock code: 600117
# Analyzing stock code: 600118
# Analyzing stock code: 600119
# Analyzing stock code: 600120
# Analyzing stock code: 600121
# Analyzing stock code: 600123
# Analyzing stock code: 600125
# Analyzing stock code: 600126
# Analyzing stock code: 600127
# Stock 600127 meets all criteria on 2024-05-21
# Analyzing stock code: 600128
# Analyzing stock code: 600129
# Analyzing stock code: 600130
# Analyzing stock code: 600131
# Analyzing stock code: 600132
# Analyzing stock code: 600133
# Analyzing stock code: 600135
# Analyzing stock code: 600136
# Analyzing stock code: 600137
# Analyzing stock code: 600138
# Analyzing stock code: 600141
# Analyzing stock code: 600143
# Analyzing stock code: 600148
# Analyzing stock code: 600149
# Analyzing stock code: 600150
# Analyzing stock code: 600151
# Analyzing stock code: 600152
# Analyzing stock code: 600153
# Analyzing stock code: 600155
# Analyzing stock code: 600156
# Analyzing stock code: 600157
# Analyzing stock code: 600158
# Analyzing stock code: 600159
# Analyzing stock code: 600160
# Analyzing stock code: 600161
# Analyzing stock code: 600162
# Analyzing stock code: 600163
# Analyzing stock code: 600165
# Analyzing stock code: 600166
# Analyzing stock code: 600167
# Analyzing stock code: 600168
# Analyzing stock code: 600169
# Analyzing stock code: 600170
# Analyzing stock code: 600171
# Analyzing stock code: 600172
# Analyzing stock code: 600173
# Analyzing stock code: 600176
# ...
# Analyzing stock code: 603182
# Analyzing stock code: 603183
# Analyzing stock code: 603185
# Analyzing stock code: 603186
